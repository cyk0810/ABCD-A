# %% [markdown]
# <a href="https://colab.research.google.com/github/cyk0810/ABCD-A/blob/20250328/11_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
samsung_price = 50000
shares_held = 10

total_value = samsung_price * shares_held

print("총 평가금액:", total_value, "원")
# Out:
# 총 평가금액: 500000 원

# %%
market_cap = 298000000000000
current_price = 50000
per = 15.79

print("시가총액:", market_cap, "원")
print("현재가:", current_price, "원")
print("PER:", per)
# Out:
# 시가총액: 298000000000000 원
# 현재가: 50000 원
# PER: 15.79

# %%
s = "hello!"
t = " python"

print(s + t)
# Out:
# hello! python

# %%
a = 2
b = 3

result = a + a * b

print(result)
# Out:
# 8
