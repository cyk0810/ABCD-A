# %% [markdown]
# <a href="https://colab.research.google.com/github/cyk0810/ABCD-A/blob/20250321/%EC%82%BC%EA%B0%81%ED%95%A8%EC%88%98%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
4/3
# Out:
# 1.3333333333333333

# %%
1/2
# Out:
# 0.5

# %%
4/2
# Out:
# 2.0

# %%
7//3
# Out:
# 2

# %%
7%3
# Out:
# 1

# %%
2**10
# Out:
# 1024

# %%
a = 11 + 2
b = 12 - 2
c = 13 * 2
d = 14 / 2
e = 15 ** 2
f = 16 // 2
g = 17 % 3
print( a, b, c, d, e, f, g)
# Out:
# 13 10 26 7.0 225 8 2

# %%
i = 3
i += 3
print(i)
i -= 3
print(i)
i *=2
print(i)
i /=2
print(int (i))
i = 3
i %=2
print(i)
# Out:
# 6
# 3
# 6
# 3
# 1

# %%
a = 10
b = 3
print("10 == 3 =>", a==b)
print("10 != 3 =>", a!=b)
print("10 > 3 =>", a>b)
print("10 >= 3 =>", a>=b)
print("10 < 3 =>", a<=b)
print("10 <= 3 =>", a<=b)
print()
# Out:
# 10 == 3 => False
# 10 != 3 => True
# 10 > 3 => True
# 10 >= 3 => True
# 10 < 3 => False
# 10 <= 3 => False

# %%
a = 13
b = 9
print(bin(a))
print(bin(b))
print(bin(a&b))
print(a&b)
# Out:
# 0b1101
# 0b1001
# 0b1001
# 9

# %%
a = 13
b = 9
print(bin(a))
print(bin(b))
print(bin(a|b))
print(a|b)
# Out:
# 0b1101
# 0b1001
# 0b1101
# 13

# %%
a = 12
b = 8
print(bin(a))
print(bin(b))
print(bin(a^b))
print('')
print(a^b)
# Out:
# 0b1100
# 0b1000
# 0b100
#
# 4

# %%
a = 12
b = 8
print(bin(a))
print(bin(~a))
# Out:
# 0b1100
# -0b1101

# %%
def gugudan(num):
    for i in range(1, 10):
      print(f'{num} x {i} = {num * i}')
    print()

gugudan (2)
# Out:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
