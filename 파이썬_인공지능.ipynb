# %% [markdown]
# <a href="https://colab.research.google.com/github/cyk0810/ABCD-A/blob/20250310/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
print('hello','everyone')
print('hello'+'everyone')

print("hello",end='!!!')
print('test')
print("hello",end='')
print('test')

a=123
b='hello'
print(a, b)
print(a, 456, b, 'world')

print('Hello"Python"')
print("Hello'Python'")
print('Hello','Python!')
print('Hello'+'Python!')

print("화면에 직접 출력")
print('ab\'c')
print("ab'c")
print ("doesn't")
print('does')
print('doesn\'t')
print ("'string'")
print("\"string\"")
print ('"string"')

s1='화면에 직접 출력'
s2='ab\'c'
s3='does'
print(s1)
print(s2)
print(s3)
print(s1[0])
print(s2[1])
print(s3[1:3])
print(s3[-1])
print(s3[-2])

a=2
b=3.1456
c=a+b
print(a)
print(b)
print(c)
print(round(c,4))
print("%.2f"%(c))
print(a+b)
print(a, b, a+b, c)
d=1e2
e=1e-2
print(d)
print(e)

item1='사과'
price1=1000
item2='바나나'
price2=500
print(item1, price1)
print(item2, price2)
str1='{0}는 {1}원 입니다.'
print(str1.format(item1, price1))
print(str1.format(item2, price2))
print(item1, price1, sep=' ', end='/')
print(item2, price2)
str2 ='%s는 %d원 입니다.'
print(str2%(item1, price1))
print(str2%(item2, price2))
# Out:
# hello
# hello everyone
# helloeveryone
# hello!!!test
# hellotest
# 123 hello
# 123 456 hello world
# Hello"Python"
# Hello'Python'
# Hello Python!
# HelloPython!
# 화면에 직접 출력
# ab'c
# ab'c
# doesn't
# does
# doesn't
# 'string'
# "string"
# "string"
# 화면에 직접 출력
# ab'c
# does
# 화
# b
# oe
# s
# e
# 2
# 3.1456
# 5.1456
# 5.1456
# 5.15
# 5.1456
# 2 3.1456 5.1456 5.1456
# 100.0
# 0.01
# 사과 1000
# 바나나 500
# 사과는 1000원 입니다.
# 바나나는 500원 입니다.
# 사과 1000/바나나 500
# 사과는 1000원 입니다.
# 바나나는 500원 입니다.
