# %% [markdown]
# <a href="https://colab.research.google.com/github/cyk0810/ABCD-A/blob/20250314/%ED%8C%8C%EC%9D%B4%EC%8D%AC_300%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Mary's cosmetics")
# Out:
# Mary's cosmetics

# %%
print('신씨가 소리를 질렀다. "도둑이야"')
# Out:
# 신씨가 소리를 질렀다. "도둑이야"

# %%
print("C:\\Windows")
# Out:
# C:\Windows

# %%
print("안녕하세요.\n만나서\t\t반갑습니다.")
# Out:
# 안녕하세요.
# 만나서		반갑습니다.

# %%
print("오늘은", "일요일")
# Out:
# 오늘은 일요일

# %%
print("naver", "kakao", "sk", "samsung", sep=';')
# Out:
# naver;kakao;sk;samsung

# %%
print("naver", "kakao", "sk", "samsung", sep='/')
# Out:
# naver/kakao/sk/samsung

# %%
print("first", end="");print("second")
# Out:
# firstsecond

# %%
print(5/3)
# Out:
# 1.6666666666666667
